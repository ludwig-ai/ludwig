# %%
import h5py
import numpy as np
import pandas as pd
import json

# %%
#generate data
from faker import Faker
from sklearn.utils import shuffle

DataGenerator = Faker()
DataGenerator.random.seed(5467)

def generate_dataset(num_records, ratio, path):
    df = pd.DataFrame(columns=(
        'transaction_id'
        , 'card_id'
        , 'customer_id'
        , 'customer_zipcode'
        , 'merchant_id'
        , 'merchant_name'
        , 'merchant_category'
        , 'merchant_zipcode'
        , 'merchant_country'
        , 'transaction_amount'
        , 'authorization_response_code'
        , 'atm_network_xid'
        , 'cvv_2_response_xflg'
        , 'fraud_label'))

    num_non_fraud = int(round(num_records * (1 - ratio)))
    num_fraud = int(round(num_records * ratio))

    for i in range(num_non_fraud):
        if i%100==0: print("{} / {}".format(i, num_non_fraud))
        row = [DataGenerator.random_int(min=100000, max=999999)
            , DataGenerator.random_int(min=9000, max=9200)
            , DataGenerator.random_int(min=1000, max=1200)
            , DataGenerator.zipcode()
            , DataGenerator.random_int(min=1, max=1000)
            , DataGenerator.company()
            , DataGenerator.random_int(min=1000, max=9999)
            , DataGenerator.zipcode()
            , DataGenerator.bank_country()
            , DataGenerator.random_int(min=1, max=2500)
            , DataGenerator.random.choice(["A", "B", "C", "D"])
            , DataGenerator.random.choice(["A", "B", "C", "D"])
            , DataGenerator.random.choice(['M', 'P', 'N'])
            , 0]
        df.loc[i] = [item for item in row]

#fraud
    for i in range(num_fraud):
        if i%100==0: print("{} / {}".format(i, num_fraud))
        row = [DataGenerator.random_int(min=100000, max=999999)
            , DataGenerator.random_int(min=9000, max=9200)
            , DataGenerator.random_int(min=1000, max=1200)
            , DataGenerator.zipcode()
            , 1011
            , 'Mums Kitchen'
            , 5813
            , 10001
            , DataGenerator.bank_country()
            , DataGenerator.random_int(min=1, max=2500)
            , DataGenerator.random.choice(["A", "B", "C", "D"])
            , DataGenerator.random.choice(["A", "B", "C", "D"])
            , DataGenerator.random.choice(['M', 'P', 'N'])
            , 1]
        df.loc[num_non_fraud+i] = [item for item in row]

    df = shuffle(df)
    df.to_csv(path, sep=',', encoding='utf-8', header=True, index = False,  mode='a')
    return df

# %%
df = generate_dataset(1000, 0.1,'transactions.csv')
# Out:
# 0 / 900
# 100 / 900
# 200 / 900
# 300 / 900
# 400 / 900
# 500 / 900
# 600 / 900
# 700 / 900
# 800 / 900
# 0 / 100

# %%
df=pd.read_csv("transactions.csv")
df
# Out:
#      transaction_id  card_id  customer_id  customer_zipcode  merchant_id  \
# 0            845944     9101         1138             61249          377
# 1            804464     9086         1054             22402          105
# 2            151495     9095         1022             95362          177
# 3            217427     9114         1139             74968          544
# 4            757416     9088         1029             31011          204
# 5            157202     9193         1010             57192          872
# 6            701451     9172         1008             16728          562
# 7            469283     9000         1077             19564          139
# 8            253931     9019         1196             93905          544
# 9            324251     9056         1040             56485          524
# 10           132021     9126         1083             35299          184
# 11           259970     9114         1051             37396          634
# 12           347416     9164         1071             50761          260
# 13           321395     9192         1040             42376          514
# 14           916690     9038         1116             69539          965
# 15           591864     9062         1064             49571          808
# 16           769337     9137         1020             12548          845
# 17           712088     9043         1085              1211         1011
# 18           352035     9125         1032             16538          602
# 19           119159     9137         1191             53388          822
# 20           493973     9024         1078             96962          125
# 21           186899     9166         1185             42578          335
# 22           700624     9028         1029             84531          389
# 23           970620     9116         1163             44963          800
# 24           602898     9065         1050             76919          304
# 25           617817     9092         1199             31261          339
# 26           267792     9148         1093             95039          918
# 27           623737     9047         1197             43674          144
# 28           469483     9003         1085             23039          893
# 29           926515     9009         1001             32218         1011
# ..              ...      ...          ...               ...          ...
# 970          896610     9009         1175             66522          152
# 971          759844     9161         1027             73010          475
# 972          436363     9191         1077             53548          695
# 973          909483     9167         1149             38550          751
# 974          192295     9101         1004             72786           21
# 975          354982     9094         1047             72007           82
# 976          844483     9019         1145             41475          504
# 977          709602     9166         1124             17583          579
# 978          492973     9085         1110             44822          687
# 979          313947     9119         1009              8664          112
# 980          394050     9176         1113             69512          784
# 981          352372     9165         1130               704           77
# 982          470081     9176         1110             83268          867
# 983          338455     9025         1120             67620          913
# 984          741916     9004         1026              7310          316
# 985          196975     9194         1147             10453          894
# 986          782727     9078         1187             96698          951
# 987          690235     9007         1065             15728         1011
# 988          903702     9126         1040             45487          339
# 989          121789     9196         1045             82494           43
# 990          291119     9153         1086             77572          865
# 991          832931     9064         1059             99077          142
# 992          648162     9102         1032              5482           22
# 993          133516     9120         1146             25430          595
# 994          886273     9090         1005             81160          712
# 995          593164     9136         1077             92057          891
# 996          909795     9040         1093             55796          733
# 997          574521     9061         1048             45656         1011
# 998          991975     9059         1166             86432          239
# 999          763299     9086         1199             85224          852
#
#                      merchant_name  merchant_category  merchant_zipcode  \
# 0     Hatfield, Collier and Vargas               2910              9672
# 1                       Nelson Inc               2101             50040
# 2                    Carson-Larson               5369             82338
# 3                     Taylor-Baker               6304             64247
# 4                      Avery-Novak               8011             75734
# 5                      Levine-Ford               3579             78745
# 6                     Archer-Clark               5631             10226
# 7                      Schmidt LLC               3272             63681
# 8                     Conrad Group               3763             20037
# 9                   Warren-Anthony               6479             96375
# 10                        Hale LLC               1318             50154
# 11                   Willis-Burton               1071             94971
# 12                     Meyer-Short               5629             65524
# 13                       Mayer Ltd               5656             87302
# 14        Miller, Miller and James               1491             60455
# 15                 Cameron-Walters               6640             14224
# 16                       Blair Inc               7810             11581
# 17                    Mums Kitchen               5813             10001
# 18                   Gutierrez Inc               4179             54443
# 19           Gray, Davis and Grant               6551             86506
# 20                    Martinez PLC               5865             38091
# 21                   Davis-Huffman               6568             77935
# 22     Nelson, Patterson and Gibbs               1883             62757
# 23                      Becker PLC               6703             19897
# 24                   Williams-West               8531             31724
# 25                      Webb-Evans               7361             81869
# 26                  Lewis and Sons               3831             14419
# 27   Cooper, Washington and Warner               2759              8022
# 28                    Wright Group               7917             91323
# 29                    Mums Kitchen               5813             10001
# ..                             ...                ...               ...
# 970                 Mitchell-Lucas               8604             10863
# 971                  Simpson Group               9396             16256
# 972                    Bradley PLC               2947             27193
# 973               Pacheco-Williams               8958             82945
# 974                 Farrell-Peters               8874             61499
# 975                Larson and Sons               2191             91386
# 976                 Warner-Chapman               9573             35096
# 977               Robbins and Sons               2229             56105
# 978                Carrillo-Foster               7319             88776
# 979                     Mendez Inc               2510             28355
# 980                     Barnes PLC               4121             30729
# 981       Smith, Holder and Guzman               9670             27135
# 982                     Gamble Inc               6671             63530
# 983     Hopkins, Green and Schmitt               3305             98834
# 984                   Smith-Rivera               2773             11956
# 985                  Gardner Group               8886             66650
# 986                    Pitts-Patel               2112             71130
# 987                   Mums Kitchen               5813             10001
# 988        Wagner, Sims and Finley               7544             97217
# 989    Mitchell, Bates and Salazar               6835             69681
# 990                 Petersen-Scott               1010             34078
# 991                      Brown Inc               8791             91631
# 992                   Guerrero LLC               4355             67794
# 993           Adams, Parker and Ho               2220              8834
# 994                  Baxter-Joseph               9402             57425
# 995                     Flores Inc               1816             31630
# 996               Pollard and Sons               1983             40451
# 997                   Mums Kitchen               5813             10001
# 998    Wells, Bailey and Rodriguez               9524             74760
# 999                     Nelson LLC               9871             51388
#
#     merchant_country  transaction_amount authorization_response_code  \
# 0                 GB                2468                           A
# 1                 GB                1168                           C
# 2                 GB                 757                           C
# 3                 GB                 966                           B
# 4                 GB                2395                           B
# 5                 GB                2283                           B
# 6                 GB                1383                           D
# 7                 GB                2346                           C
# 8                 GB                1849                           C
# 9                 GB                1705                           A
# 10                GB                 882                           A
# 11                GB                2385                           D
# 12                GB                  45                           B
# 13                GB                1228                           C
# 14                GB                2225                           A
# 15                GB                2400                           A
# 16                GB                2475                           C
# 17                GB                 372                           D
# 18                GB                2005                           B
# 19                GB                1170                           C
# 20                GB                2500                           B
# 21                GB                2394                           A
# 22                GB                2340                           B
# 23                GB                2190                           D
# 24                GB                 252                           A
# 25                GB                1096                           C
# 26                GB                2159                           A
# 27                GB                1785                           B
# 28                GB                1962                           C
# 29                GB                1643                           C
# ..               ...                 ...                         ...
# 970               GB                1794                           C
# 971               GB                1399                           D
# 972               GB                1284                           C
# 973               GB                 760                           D
# 974               GB                 702                           D
# 975               GB                 392                           D
# 976               GB                 801                           A
# 977               GB                1255                           B
# 978               GB                1015                           A
# 979               GB                1715                           D
# 980               GB                 288                           A
# 981               GB                1833                           C
# 982               GB                2458                           D
# 983               GB                1540                           A
# 984               GB                1060                           D
# 985               GB                1362                           B
# 986               GB                1285                           D
# 987               GB                 220                           D
# 988               GB                 914                           B
# 989               GB                1763                           C
# 990               GB                1292                           C
# 991               GB                 474                           C
# 992               GB                 653                           A
# 993               GB                1529                           A
# 994               GB                 330                           A
# 995               GB                1963                           B
# 996               GB                1797                           A
# 997               GB                1910                           A
# 998               GB                1638                           C
# 999               GB                 518                           C
#
#     atm_network_xid cvv_2_response_xflg  fraud_label
# 0                 B                   N            0
# 1                 B                   N            0
# 2                 C                   M            0
# 3                 C                   N            0
# 4                 B                   P            0
# 5                 B                   M            0
# 6                 A                   N            0
# 7                 A                   P            0
# 8                 C                   M            0
# 9                 C                   M            0
# 10                C                   M            0
# 11                C                   P            0
# 12                D                   P            0
# 13                B                   M            0
# 14                B                   P            0
# 15                A                   P            0
# 16                A                   M            0
# 17                C                   M            1
# 18                B                   P            0
# 19                B                   M            0
# 20                D                   M            0
# 21                C                   M            0
# 22                C                   N            0
# 23                D                   P            0
# 24                D                   N            0
# 25                C                   N            0
# 26                D                   P            0
# 27                B                   M            0
# 28                C                   N            0
# 29                D                   M            1
# ..              ...                 ...          ...
# 970               C                   P            0
# 971               A                   M            0
# 972               B                   N            0
# 973               C                   M            0
# 974               B                   P            0
# 975               C                   N            0
# 976               B                   N            0
# 977               D                   N            0
# 978               A                   P            0
# 979               A                   P            0
# 980               A                   M            0
# 981               B                   N            0
# 982               D                   N            0
# 983               A                   N            0
# 984               C                   N            0
# 985               D                   P            0
# 986               A                   M            0
# 987               D                   N            1
# 988               A                   M            0
# 989               B                   P            0
# 990               B                   M            0
# 991               D                   N            0
# 992               C                   M            0
# 993               A                   N            0
# 994               D                   N            0
# 995               A                   P            0
# 996               A                   N            0
# 997               B                   M            1
# 998               D                   P            0
# 999               D                   M            0
#
# [1000 rows x 14 columns]

# %% [markdown]
# now that i have a dataset, i want to extract the metadata then reshape into sequence of transactions.  ultimately we need to adapt meta-data extractor to do this, but for now i will run ludwig with a base transaction oriented model solely for the purposes of generating the metadata.

# %%
from ludwig import LudwigModel
import logging
model = LudwigModel({}, model_definition_file='base_model.yaml', logging_level=logging.INFO)

# %%
train_stats = model.train(data_csv='transactions.csv')

# %%
df = pd.read_csv('transactions.csv')

# %%
g = df.groupby(['customer_id'])

# %%
customer_id = []
merchant_category = []
merchant_zipcode = []
transaction_amount = []
label = []

#this is quick and dirty just to get the right shape..in reality there are more examples that should be extracted.
for n, grp in g:
    s = grp.reset_index(drop=True)
  
    if s.shape[0] < 6:
        continue
    label.append(s['fraud_label'][0])
    customer_id.append(str(n))
    merchant_category.append(np.array(s['merchant_category'][0:5].astype(str)))
    merchant_zipcode.append(np.array(s['merchant_zipcode'][0:5].astype(str)))
    transaction_amount.append(np.array(s['transaction_amount'][0:5]))

# %%
split = np.random.choice([0,1,2], size=len(customer_id), p=[0.8, 0.1, 0.1])

# %%
def load_json(data_fp):
    with open(data_fp, 'r') as input_file:
        data = json.load(input_file)
        return data


def load_hdf5(data_fp):
    data = {}
    with h5py.File(data_fp, 'r') as h5_file:
        for key in h5_file.keys():
            data[key] = h5_file[key].value
    return data

# %%
#integerize
metadata = load_json('transactions.json')

mc = [[metadata['merchant_category']['str2idx'][a] for a in b] for b in merchant_category]
mz = [[metadata['merchant_zipcode']['str2idx'][a] for a in b] for b in merchant_zipcode]
ci = [metadata['customer_id']['str2idx'][a] for a in customer_id]

# %%
metadata = load_json('transactions.json')
with h5py.File('sequence_dataset.hdf5', 'w') as h5_file:
    h5_file.create_dataset('customer_id', data=np.array(ci))
    h5_file.create_dataset('merchant_category', data=np.array(mc))
    h5_file.create_dataset('merchant_zipcode', data=np.array(mz))
    h5_file.create_dataset('transaction_amount', data=np.array(transaction_amount))
    h5_file.create_dataset('fraud_label', data=np.array(label))
    h5_file.create_dataset('split', data=np.array(split))

# %% [markdown]
# Now we build the real model.
# note that we first need to adjust the metadata file

# %%
# !cp transactions.json sequence_dataset.json
#edit manually to add ax sequence lengths for all of the features what will be sequences. (this is already done)

# %%
model = LudwigModel({}, model_definition_file='model.yaml', logging_level=logging.INFO)

# %%
train_stats = model.train(data_hdf5='sequence_dataset.hdf5', train_set_metadata_json='sequence_dataset.json')
# Out:
# WARNING:tensorflow:From /Users/benmackenzie/projects/ludwig/venv/lib/python3.6/site-packages/ludwig-0.1.0-py3.6.egg/ludwig/models/combiners.py:239: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# /Users/benmackenzie/projects/ludwig/venv/lib/python3.6/site-packages/h5py/_hl/dataset.py:313: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   "Use dataset[()] instead.", H5pyDeprecationWarning)
# WARNING:tensorflow:From /Users/benmackenzie/projects/ludwig/venv/lib/python3.6/site-packages/ludwig-0.1.0-py3.6.egg/ludwig/models/combiners.py:239: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /Users/benmackenzie/projects/ludwig/venv/lib/python3.6/site-packages/ludwig-0.1.0-py3.6.egg/ludwig/models/modules/recurrent_modules.py:201: BasicRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.SimpleRNNCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /Users/benmackenzie/projects/ludwig/venv/lib/python3.6/site-packages/ludwig-0.1.0-py3.6.egg/ludwig/models/modules/recurrent_modules.py:201: BasicRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.SimpleRNNCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /Users/benmackenzie/projects/ludwig/venv/lib/python3.6/site-packages/ludwig-0.1.0-py3.6.egg/ludwig/models/modules/recurrent_modules.py:204: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /Users/benmackenzie/projects/ludwig/venv/lib/python3.6/site-packages/ludwig-0.1.0-py3.6.egg/ludwig/models/modules/recurrent_modules.py:204: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /Users/benmackenzie/projects/ludwig/venv/lib/python3.6/site-packages/ludwig-0.1.0-py3.6.egg/ludwig/models/modules/recurrent_modules.py:209: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /Users/benmackenzie/projects/ludwig/venv/lib/python3.6/site-packages/ludwig-0.1.0-py3.6.egg/ludwig/models/modules/recurrent_modules.py:209: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-66ee53b4fbd3> in <module>
# ----> 1 train_stats = model.train(data_hdf5='sequence_dataset.hdf5', train_set_metadata_json='sequence_dataset.json')
#
# ~/projects/ludwig/venv/lib/python3.6/site-packages/ludwig-0.1.0-py3.6.egg/ludwig/api.py in train(self, data_df, data_train_df, data_validation_df, data_test_df, data_csv, data_train_csv, data_validation_csv, data_test_csv, data_hdf5, data_train_hdf5, data_validation_hdf5, data_test_hdf5, train_set_metadata_json, dataset_type, model_name, model_load_path, model_resume_path, skip_save_model, skip_save_progress, skip_save_log, skip_save_processed_input, output_directory, gpus, gpu_fraction, random_seed, logging_level, debug, **kwargs)
#     513             gpu_fraction=gpu_fraction,
#     514             random_seed=random_seed,
# --> 515             debug=debug
#     516         )
#     517
#
# ~/projects/ludwig/venv/lib/python3.6/site-packages/ludwig-0.1.0-py3.6.egg/ludwig/train.py in train(training_set, validation_set, test_set, model_definition, save_path, model_load_path, resume, skip_save_model, skip_save_progress, skip_save_log, gpus, gpu_fraction, use_horovod, random_seed, debug)
#     424         gpus=gpus, gpu_fraction=gpu_fraction,
#     425         random_seed=random_seed,
# --> 426         **model_definition['training']
#     427     )
#     428
#
# ~/projects/ludwig/venv/lib/python3.6/site-packages/ludwig-0.1.0-py3.6.egg/ludwig/models/model.py in train(self, training_set, validation_set, test_set, validation_field, validation_measure, save_path, regularization_lambda, epochs, learning_rate, batch_size, bucketing_field, dropout_rate, early_stop, reduce_learning_rate_on_plateau, reduce_learning_rate_on_plateau_patience, reduce_learning_rate_on_plateau_rate, increase_batch_size_on_plateau, increase_batch_size_on_plateau_patience, increase_batch_size_on_plateau_rate, increase_batch_size_on_plateau_max, learning_rate_warmup_epochs, resume, skip_save_model, skip_save_progress, skip_save_log, gpus, gpu_fraction, random_seed, **kwargs)
#     513                         learning_rate=current_learning_rate,
#     514                         dropout_rate=dropout_rate,
# --> 515                         is_training=True
#     516                     )
#     517                 )
#
# ~/projects/ludwig/venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/projects/ludwig/venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126                              'which has shape %r' %
#    1127                              (np_val.shape, subfeed_t.name,
# -> 1128                               str(subfeed_t.get_shape())))
#    1129           if not self.graph.is_feedable(subfeed_t):
#    1130             raise ValueError('Tensor %s may not be fed.' % subfeed_t)
#
# ValueError: Cannot feed value of shape (65, 5) for Tensor 'transaction_amount/transaction_amount_placeholder:0', which has shape '(?, 6)'

# %%
train_stats
# Out:
# {'train': OrderedDict([('fraud_label',
#                OrderedDict([('loss',
#                              [59.635194242670295,
#                               23.02798599071717,
#                               1.0479783797531985,
#                               2.92749182026038,
#                               3.6576714676417663,
#                               3.727519838997487,
#                               3.4118640342455233,
#                               2.877492326029231]),
#                             ('accuracy',
#                              [0.10814606741573034,
#                               0.11376404494382023,
#                               0.9002808988764045,
#                               0.9002808988764045,
#                               0.9030898876404494,
#                               0.9058988764044944,
#                               0.9058988764044944,
#                               0.9143258426966292])])),
#               ('combined',
#                {'loss': [59.635194242670295,
#                  23.02798599071717,
#                  1.0479783797531985,
#                  2.92749182026038,
#                  3.6576714676417663,
#                  3.727519838997487,
#                  3.4118640342455233,
#                  2.877492326029231],
#                 'accuracy': [0.10814606741573034,
#                  0.11376404494382023,
#                  0.9002808988764045,
#                  0.9002808988764045,
#                  0.9030898876404494,
#                  0.9058988764044944,
#                  0.9058988764044944,
#                  0.9143258426966292]})]),
#  'validation': OrderedDict([('fraud_label',
#                OrderedDict([('loss',
#                              [51.87758953651685,
#                               20.09094512596559,
#                               1.251480788327335,
#                               3.428730139571629,
#                               4.271907849258252,
#                               4.354414350531075,
#                               3.999734599938553,
#                               3.387388765142205]),
#                             ('accuracy',
#                              [0.12359550561797752,
#                               0.14606741573033707,
#                               0.8876404494382022,
#                               0.8876404494382022,
#                               0.8876404494382022,
#                               0.8876404494382022,
#                               0.898876404494382,
#                               0.898876404494382])])),
#               ('combined',
#                {'loss': [51.87758953651685,
#                  20.09094512596559,
#                  1.251480788327335,
#                  3.428730139571629,
#                  4.271907849258252,
#                  4.354414350531075,
#                  3.999734599938553,
#                  3.387388765142205],
#                 'accuracy': [0.12359550561797752,
#                  0.14606741573033707,
#                  0.8876404494382022,
#                  0.8876404494382022,
#                  0.8876404494382022,
#                  0.8876404494382022,
#                  0.898876404494382,
#                  0.898876404494382]})]),
#  'test': OrderedDict([('fraud_label',
#                OrderedDict([('loss',
#                              [63.54926978643216,
#                               24.68685161648084,
#                               0.8011834992835271,
#                               2.1794088545756125,
#                               2.7080395569154367,
#                               2.748687130721969,
#                               2.5032580198355054,
#                               2.097495150925526]),
#                             ('accuracy',
#                              [0.08542713567839195,
#                               0.08542713567839195,
#                               0.914572864321608,
#                               0.914572864321608,
#                               0.9246231155778895,
#                               0.9246231155778895,
#                               0.9246231155778895,
#                               0.9346733668341709])])),
#               ('combined',
#                {'loss': [63.54926978643216,
#                  24.68685161648084,
#                  0.8011834992835271,
#                  2.1794088545756125,
#                  2.7080395569154367,
#                  2.748687130721969,
#                  2.5032580198355054,
#                  2.097495150925526],
#                 'accuracy': [0.08542713567839195,
#                  0.08542713567839195,
#                  0.914572864321608,
#                  0.914572864321608,
#                  0.9246231155778895,
#                  0.9246231155778895,
#                  0.9246231155778895,
#                  0.9346733668341709]})])}
